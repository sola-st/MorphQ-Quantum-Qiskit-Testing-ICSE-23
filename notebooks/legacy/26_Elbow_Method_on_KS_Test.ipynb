# %% [markdown]
# ## Benchmark Goal

# %%
# GOAL: check if the elbow method applied on the statistic of the KS Test 
# could give as good results as the energy test. 
# INTUITION: maybe the threshold of 0.05 p-value is not adapt for this problem

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../lib")
import seaborn as sns
import matplotlib.pyplot as plt
from utils import iterate_over
from utils import load_config_and_check
import os

# %%
config_train = load_config_and_check("../config/experiment_v09.yaml")
config_test = load_config_and_check("../config/experiment_v10.yaml")

# %%
OUT_IMAGE_PATH = "../data/paper_images"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from analyser import Explorer

# %% [markdown]
# ## Training: identify the thresholds (median/50%)

# %%
exp_train = Explorer(config_train)
# Out:
# --- PROGRAM INFO ---
# - BENCHMARK: qasm_bench_mid ...
# - BENCHMARK: tket_bench_1 ...
# - BENCHMARK: across_runs_qiskit ...
# - BENCHMARK: across_runs_cirq ...
# - BENCHMARK: program_vs_random ...
# - BENCHMARK: negation ...
# - BENCHMARK: program_x_vs_program_y ...
# --- EXECUTION INFO ---
# - BENCHMARK: qasm_bench_mid ...
# - BENCHMARK: tket_bench_1 ...
# - BENCHMARK: across_runs_qiskit ...
# - BENCHMARK: across_runs_cirq ...
# - BENCHMARK: program_vs_random ...
# - BENCHMARK: negation ...
# - BENCHMARK: program_x_vs_program_y ...
# --- GROUND TRUTH ---
# - BENCHMARK: qasm_bench_mid) ...
# - BENCHMARK: tket_bench_1) ...
# - BENCHMARK: across_runs_qiskit) ...
# - BENCHMARK: across_runs_cirq) ...
# - BENCHMARK: program_vs_random) ...
# - BENCHMARK: negation) ...
# - BENCHMARK: program_x_vs_program_y) ...
# --- DETECTOR DATA ---
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v09/qasm_bench_mid/predictions/js.
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v09/qasm_bench_mid/predictions/energy.
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v09/qasm_bench_mid/predictions/ks.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v09/tket_bench_1/predictions/js.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v09/tket_bench_1/predictions/energy.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v09/tket_bench_1/predictions/ks.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v09/across_runs_qiskit/predictions/js.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v09/across_runs_qiskit/predictions/energy.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v09/across_runs_qiskit/predictions/ks.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v09/across_runs_cirq/predictions/js.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v09/across_runs_cirq/predictions/energy.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v09/across_runs_cirq/predictions/ks.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v09/program_vs_random/predictions/js.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v09/program_vs_random/predictions/energy.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v09/program_vs_random/predictions/ks.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v09/negation/predictions/js.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v09/negation/predictions/energy.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v09/negation/predictions/ks.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v09/program_x_vs_program_y/predictions/js.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v09/program_x_vs_program_y/predictions/energy.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v09/program_x_vs_program_y/predictions/ks.

# %%
len(exp_train.df_all)
# Out:
# 2444

# %%
df = exp_train.df_all
series = df["test"]
print(series)
# Out:
# 0      energy
# 1          js
# 2          ks
# 3      energy
# 4          js
#         ...
# 606    random
# 607    random
# 608    random
# 609    random
# 610    random
# Name: test, Length: 2444, dtype: object

# %%
TEST_NAMES = exp_train.get_available_tests()
n_test = len(test_names)

np.random.seed(5)

fig, axes = plt.subplots(1, n_test, figsize=(n_test * 5, 5))

for i, test_name in enumerate(TEST_NAMES):
    ax = axes[i]
    exp_train.focus_on_detector(detector_name=test_name)
    exp_train.inspect(
        variable_to_inspect='statistic', 
        title=f"Distribution of {test_name} detector (TRAINING)",
        ax=ax,
        color=np.random.rand(3,)
    )
# Out:
# We have displayed 611/611 datapoints.
# [benchmark restriction: None]
# We have displayed 611/611 datapoints.
# [benchmark restriction: None]
# We have displayed 611/611 datapoints.
# [benchmark restriction: None]
# We have displayed 611/611 datapoints.
# [benchmark restriction: None]

# %%
TEST_THRESHOLDS = {}

for test_name in TEST_NAMES:
    TEST_THRESHOLDS[test_name] = exp_train.plot_ECDF(test_name=test_name, variable="statistic")

# %%
fig_ecdf, ax_ecdf = plt.subplots(figsize=(5, 2.5))

fig_derviv, ax_deriv = plt.subplots(figsize=(5, 5))
threshold_ks = exp_train.plot_ECDF(test_name="ks", variable="statistic", 
                                   ax_ecdf=ax_ecdf, ax_deriv=ax_deriv)
#fig_ecdf.savefig(os.path.join(OUT_IMAGE_PATH, "threshold_method.pdf"), format="pdf")

# %% [markdown]
# ## Testing: Benchmark Categories

# %%
exp_test = Explorer(config_test)
# Out:
# --- PROGRAM INFO ---
# - BENCHMARK: qasm_bench_mid ...
# - BENCHMARK: tket_bench_1 ...
# - BENCHMARK: across_runs_qiskit ...
# - BENCHMARK: across_runs_cirq ...
# - BENCHMARK: program_vs_random ...
# - BENCHMARK: negation ...
# - BENCHMARK: program_x_vs_program_y ...
# --- EXECUTION INFO ---
# - BENCHMARK: qasm_bench_mid ...
# - BENCHMARK: tket_bench_1 ...
# - BENCHMARK: across_runs_qiskit ...
# - BENCHMARK: across_runs_cirq ...
# - BENCHMARK: program_vs_random ...
# - BENCHMARK: negation ...
# - BENCHMARK: program_x_vs_program_y ...
# --- GROUND TRUTH ---
# - BENCHMARK: qasm_bench_mid) ...
# - BENCHMARK: tket_bench_1) ...
# - BENCHMARK: across_runs_qiskit) ...
# - BENCHMARK: across_runs_cirq) ...
# - BENCHMARK: program_vs_random) ...
# - BENCHMARK: negation) ...
# - BENCHMARK: program_x_vs_program_y) ...
# --- DETECTOR DATA ---
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v10/qasm_bench_mid/predictions/js.
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v10/qasm_bench_mid/predictions/energy.
#  - BENCHMARK: qasm_bench_mid - DETECTOR: ../data/experiment_v10/qasm_bench_mid/predictions/ks.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v10/tket_bench_1/predictions/js.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v10/tket_bench_1/predictions/energy.
#  - BENCHMARK: tket_bench_1 - DETECTOR: ../data/experiment_v10/tket_bench_1/predictions/ks.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v10/across_runs_qiskit/predictions/js.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v10/across_runs_qiskit/predictions/energy.
#  - BENCHMARK: across_runs_qiskit - DETECTOR: ../data/experiment_v10/across_runs_qiskit/predictions/ks.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v10/across_runs_cirq/predictions/js.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v10/across_runs_cirq/predictions/energy.
#  - BENCHMARK: across_runs_cirq - DETECTOR: ../data/experiment_v10/across_runs_cirq/predictions/ks.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v10/program_vs_random/predictions/js.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v10/program_vs_random/predictions/energy.
#  - BENCHMARK: program_vs_random - DETECTOR: ../data/experiment_v10/program_vs_random/predictions/ks.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v10/negation/predictions/js.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v10/negation/predictions/energy.
#  - BENCHMARK: negation - DETECTOR: ../data/experiment_v10/negation/predictions/ks.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v10/program_x_vs_program_y/predictions/js.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v10/program_x_vs_program_y/predictions/energy.
#  - BENCHMARK: program_x_vs_program_y - DETECTOR: ../data/experiment_v10/program_x_vs_program_y/predictions/ks.

# %%
TEST_TO_PRINT = [
    "ks", 
    "js", 
    "energy", 
    "random"
]

n_tests = len(TEST_TO_PRINT)

fig, axes = plt.subplots(n_tests, 1, figsize=(5, 2.15 * n_tests))

for i, test_name in enumerate(TEST_TO_PRINT):

    exp_test.reset_test_level(detector_name=test_name)
    exp_test.classify_based_on(col_name="statistic", 
                               threshold=TEST_THRESHOLDS[test_name], reject_if_low=False)
    exp_test.plot_benchmark_categories(ax=axes[i])
plt.tight_layout()
fig.savefig(os.path.join(OUT_IMAGE_PATH, "perf_benchmark_categories.pdf"), format="pdf")

# %% [markdown]
# ## Testing: ROC-AUC

# %%
fig, ax = plt.subplots(figsize=(5, 5))
exp_test.plot_ROC(prediction_column="p_value", low_reject=True, title="P-value based")
exp_test.plot_ROC(prediction_column="statistic", low_reject=False, title="Statistic-based", ax=ax)
fig.savefig(os.path.join(OUT_IMAGE_PATH, "perf_benchmark_ROC_AUC.pdf"), format="pdf")

# %% [markdown]
# ## Dataset Distribution

# %%
from collections import Counter

exp_test.reset()
df_all = exp_test.df_all
# get results for only one test
df_all = df_all[df_all["test"] == "ks"]
n_records = len(df_all)

cnt = Counter(df_all["expected_divergence"])

n_true_divergence_benchmark = cnt[True]
perc_true_divergence_benchmark = (n_true_divergence_benchmark / n_records) * 100
n_false_divergence_benchmark = cnt[False]
perc_false_divergence_benchmark = (n_false_divergence_benchmark / n_records) * 100

print("\\newcommand{\\nTrueDivergenceBenchmark}{" + f"{n_true_divergence_benchmark:.0f}" + "}")
print("\\newcommand{\\percTrueDivergenceBenchmark}{" + f"{perc_true_divergence_benchmark:.1f}\\%" + "}")
print("\\newcommand{\\nFalseDivergenceBenchmark}{" + f"{n_false_divergence_benchmark:.0f}" + "}")
print("\\newcommand{\\percFalseDivergenceBenchmark}{" + f"{perc_false_divergence_benchmark:.1f}\\%" + "}")
# Out:
# \newcommand{\nTrueDivergenceBenchmark}{300}
# \newcommand{\percTrueDivergenceBenchmark}{49.1\%}
# \newcommand{\nFalseDivergenceBenchmark}{311}
# \newcommand{\percFalseDivergenceBenchmark}{50.9\%}

# %% [markdown]
# ## Old elbow zoom

# %%
def plot_elbow_with_threshold(df, threshold=0.5):
    """Visualize the elbow diagram with a potential threshold."""
    fig, axes = plt.subplots(1, 3, figsize=(15,3))
    ax_super_zoom = axes[2]
    ax_zoom = axes[1]
    ax_normal = axes[0]

    sns.ecdfplot(
        data=df,
        x="statistic",
        ax=ax_normal
    )
    ax_normal.set_title("Full Scale")

    sns.ecdfplot(
        data=df,
        x="statistic",
        ax=ax_zoom
    )
    ax_zoom.set_xlim(0,0.05)
    ax_zoom.set_title("Zoom")

    sns.ecdfplot(
        data=df,
        x="statistic",
        ax=ax_super_zoom
    )
    ax_super_zoom.set_xlim(0,0.007)
    ax_super_zoom.set_title("Super Zoom")

    THRESHOLD_ON_STATISTIC = .001
    ax_normal.axvline(x=threshold, color='r')
    ax_zoom.axvline(x=threshold, color='r')
    ax_super_zoom.axvline(x=threshold, color='r')
    print(f"We raise an alert for all the data with a statistic higher than: {threshold}")

# %%
plot_elbow_with_threshold(df=df_ks, threshold=0.02)
# Out:
# We raise an alert for all the data with a statistic higher than: 0.02
